# %%
from matplotlib import pylab 
print(pylab.__version__)
# Out:
# 1.21.5

# %%
import numpy as np

X = np.linspace(0,10,25)
Y = X * X + 2
print(X)
print(Y)
print(np.array([X,Y]).reshape(25,2).reshape(2,25))
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]
# [[  0.           0.41666667   0.83333333   1.25         1.66666667
#     2.08333333   2.5          2.91666667   3.33333333   3.75
#     4.16666667   4.58333333   5.           5.41666667   5.83333333
#     6.25         6.66666667   7.08333333   7.5          7.91666667
#     8.33333333   8.75         9.16666667   9.58333333  10.        ]
#  [  2.           2.17361111   2.69444444   3.5625       4.77777778
#     6.34027778   8.25        10.50694444  13.11111111  16.0625
#    19.36111111  23.00694444  27.          31.34027778  36.02777778
#    41.0625      46.44444444  52.17361111  58.25        64.67361111
#    71.44444444  78.5625      86.02777778  93.84027778 102.        ]]

# %%
pylab.plot(X,Y,'r')

# %%
pylab.subplot(1,2,1)
pylab.plot(X,Y,'r--')
pylab.subplot(1,2,2)
pylab.plot(Y,X,'g*-')

# %%
pylab.subplot(1,2,1)
pylab.plot(X,Y,'r--')
pylab.subplot(1,2,1)
pylab.plot(Y,X,'g*-')

# %%
from matplotlib import pyplot as plt

# %%
Fig = plt.figure()
Axis = Fig.add_axes([0.5,0.1,0.8,0.8])
Axis.plot(X,Y,'r')

# %%
Fig, Axes = plt.subplots(nrows=1, ncols=2)
for ax in Axes:
    ax.plot(X,Y,'r')

# %%
Fig = plt.figure()
Axes1 = Fig.add_axes([0.1,0.1,0.8,0.8])
Axes2 = Fig.add_axes([0.2,0.5,0.2,0.2])
Axes1.plot(X,Y,'r')
Axes2.plot(Y,X,'g')

# %%
Fig = plt.figure(figsize=(16,9), dpi=100)
Axis = Fig.add_axes([0.5,0.1,0.8,0.8])
Axis.plot(X,Y,'r')

# %%
ax.legend(['Label1, Label2'])
Fig, Axes = plt.subplots(dpi=200)
Axes.set_xlabel('X-Label')
Axes.set_ylabel('Y-Label')
Axes.set_title('Title of Graph')
Axes.plot(X, X**2)
Axes.plot(X, X**3)
Axes.legend(['Y = X**2, Y = X**3'], loc=2)

# %%
Fig, Axes = plt.subplots(dpi=150)
Axes.plot(X, X**2, color='Red', alpha=0.8)
Axes.plot(X, X+2, color='Blue', alpha=0.8)
Axes.plot(X, X+3, color='Green', alpha=0.8)

# %%
Fig, ax = plt.subplots(dpi=100)
ax.plot(X, X+1, color='Blue', linewidth=0.25)
ax.plot(X, X+2, color='Blue', linewidth=1)
ax.plot(X, X+3, color='Blue', linewidth=1.5)
ax.plot(X, X+4, color='Blue', linewidth=2)

# %%
Fig, ax = plt.subplots(dpi=100)
ax.plot(X, X+1, color='Blue', lw=2, linestyle='-')
ax.plot(X, X+2, color='Blue', lw=2, linestyle='-.')
ax.plot(X, X+3, color='Blue', lw=2, linestyle=':')
Line, = ax.plot(X, X+4, color='Black', lw=1.50)
Line.set_dashes([5,10,15,10])
Line, = ax.plot(X, X+5, color='Black', lw=1.50)
Line.set_dashes([5,10,15,3])
Line, = ax.plot(X, X+6, color='Black', lw=1.50)
Line.set_dashes([5,10,30,30])

# %%
Fix, ax = plt.subplots(dpi=100)
ax.plot(X, X+1, color='Blue', marker='o')
ax.plot(X, X+2, color='Blue', marker='+')
ax.plot(X, X+3, color='Blue', marker='s')
ax.plot(X, X+4, color='Blue', marker='1')
ax.plot(X, X+5, color='Blue', marker='o', markersize=5)
ax.plot(X, X+6, color='Blue', marker='s', markerfacecolor='Red')
ax.plot(X, X+7, color='Blue', marker='o', markersize=8, markerfacecolor='Green')

# %%
Fig, Axes = plt.subplots(1,2, figsize=(10,5))
Axes[0].plot(X, X**2, X, X**3, lw=2)
Axes[0].grid(True)
Axes[1].plot(X, X**2, X, X**3, lw=2)
Axes[0].grid(True)
Axes[1].set_ylim([0,60])
Axes[1].set_xlim([2,5])
# Out:
# (2.0, 5.0)

# %%
N = np.array([0,1,2,3,4,5])
Fix, Axes = plt.subplots(1,4, figsize=(16,5))
Axes[0].set_title('Scatter')
Axes[0].scatter(X, X + 0.25*np.random.randn(len(X)))
Axes[1].set_title('Step')
Axes[1].step(N, N**2, lw=2)
Axes[2].set_title('Bar')
Axes[2].bar(N, N**2)
Axes[3].set_title('Fill_Between')
Axes[3].fill_between(X, X**2, X**3, color='Green', alpha=0.5)

# %%
Fig = plt.figure(figsize=(6,6))
Ax = Fig.add_axes([0.0,0.0,1,1], polar=True)
T = np.linspace(0,2*np.pi,100)
Ax.plot(T,T*0.5,color='Blue',lw=3)

# %%
N = np.random.randn(100000)
Fig, Axes = plt.subplots(1,2, figsize=(12,4))
Axes[0].set_title('Default Histogram')
Axes[0].hist(N)
Axes[1].set_title('Cumulative Detailed Histogram')
Axes[1].hist(N, cumulative=True, bins=10)
# Out:
# (array([7.4000e+01, 9.5900e+02, 6.9050e+03, 2.5988e+04, 5.7909e+04,
#         8.5045e+04, 9.7041e+04, 9.9678e+04, 9.9984e+04, 1.0000e+05]),
#  array([-4.00869676, -3.16768016, -2.32666355, -1.48564694, -0.64463033,
#          0.19638627,  1.03740288,  1.87841949,  2.71943609,  3.5604527 ,
#          4.40146931]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

Delta = 0.025
x = np.arange(-3.0,3.0,Delta)
y = np.arange(-2.0,2.0,Delta)
X, Y, = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2
print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
Fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('Contour Map')
# Out:
# Text(0.5, 1.0, 'Contour Map')

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
Fig = plt.figure(figsize=(14,6))
Ax = Fig.add_subplot(1,2,1, projection='3d')
Ax.plot_surface(X,Y,Z, rstride=4, cstride=4, linewidth=0)

# %%
import matplotlib.pyplot as plt

lang = 'Python', 'Java', 'PHP', 'JavaScript', 'C#', 'C++'
Pop = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['red', 'blue', 'green', 'orange', 'yellow', 'tan']

# %%
explode = (0.1,0,0,0,0,0)
plt.pie(Pop, explode=explode, labels=lang, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1745d6430>,
#   <matplotlib.patches.Wedge at 0x1745d6dc0>,
#   <matplotlib.patches.Wedge at 0x1745e0790>,
#   <matplotlib.patches.Wedge at 0x1745e9160>,
#   <matplotlib.patches.Wedge at 0x1745e9af0>,
#   <matplotlib.patches.Wedge at 0x1745f14c0>],
#  [Text(-0.9981321564304079, 0.6661322678714672, 'Python'),
#   Text(-0.42656614184011216, -1.0139237282141302, 'Java'),
#   Text(0.7656789278855427, -0.7897694469856669, 'PHP'),
#   Text(1.0981806733680344, -0.06323929665114078, 'JavaScript'),
#   Text(0.8841620379545417, 0.6544138527262939, 'C#'),
#   Text(0.321350164763084, 1.0520142924916651, 'C++')],
#  [Text(-0.5822437579177379, 0.3885771562583558, '31.3%'),
#   Text(-0.23267244100369752, -0.5530493062986164, '24.8%'),
#   Text(0.4176430515739324, -0.4307833347194546, '12.4%'),
#   Text(0.5990076400189277, -0.034494161809713146, '11.3%'),
#   Text(0.48227020252065905, 0.3569530105779785, '10.8%'),
#   Text(0.17528190805259122, 0.5738259777227264, '9.4%')])
